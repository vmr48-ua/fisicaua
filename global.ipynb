# %%
alumnos = [
    ('Lucía Alberola',(('US CLEMSON',7.22),('US FLAGSTA01',7.22),('US PHILADE01',7.22),('US NEW-YOR01',7.22),('US MACOMB01',7.22),('US CLARKSV01',7.22),('AR BUENOSA01',6.22),('JP KYOTO01',7.22),('PE LIMA02',6.22),('RCH VINADEL01',6.22),('RCH SANTIAG05',6.22),('RCH SANTIAG02',6.22),('RCH SANTIAG04',6.22),('BR RIOJAN01',7.22))),
    ('María Alfaro',6.85,('RCH SANTIAG05','RCH SANTIAG05','UY MONTEVI01','AR BUENOSA03','ME MEXICO02')),
    ('Pablo Alemany',7.9,('KR SEOUL02','KR SEOUL03','US CLEMSON','MY SUBANG-01','US TEMPE01','BR RIOJAN01')),
    ('Gabriela Alvarez',6.1,('RCH SANTIAG04','PY ASUNCIO01','AR BUENOSA01')),
    ('Maria del Carmen Amador',6.24,('NZ HAMILTO01','AU ARMIDAL01','JP NISHINO01','JP KYOTO01')),
    ('Sara Anton',7.1,('US CLEMSON','')),
    ('Sandra Assaf',(('EC QUITO03',5.59),('JP NISHINO01',6.59),('ME MEXICO02',5.59),('EC QUITO02',5.59),('PE LIMA03',5.59),('CO CALI01',5.59))),
    ('Jorge Astillero',9.09,('US CLEMSON','US TALLAHA01','NZ HAMILTO01','US FLAGSTA01','US GREELEY01','JP KYOTO01')),
    ('Llorenç Boquer',(('NZ HAMILTO01',6.15),('AU ARMIDAL01',6.15),('US TALLAHA01',6.15),('US TEMPE01',6.15),('CDN QUEBEC',7.15),('CDNQUEBEC03',7.15),('BR FLORIAN01',6.15),('KR SEOUL02',6.15),('JP KYOTO01',6.15))),
    ('Bartel Prieto',5.48,('UY MONTEVI03','')),
    ('Marta Baños',6.94,('RCH SANTIAG03','RCH SANTIAG01','RCH SANTIAG04','RCH SANTIAG05','RCH SANTIAG02','AR SANTAFE01')),
    ('Virtudes María Bermejo',6.74,('RCH SANTIAG04','RCH SANTIAG01','RCH SANTIAG05','RCH VINADEL01','PE LIMA01','PE LIMA02','AR SANTAFE01','AR BUENOSA03')),
    ('Celia Bernal',(('US NEW-YOR01',7.58),('AU ARMIDAL01',7.58),('US GREELEY01',7.58),('US FLAGSTA01',7.58),('NZ HAMILTO01',7.58),('JP NISHINO01',7.58),('JP KYOTO01',7.58),('AR BUENOSA01',6.58))),
    ('Rosa Bolta',5.96,('AR SANTAFE01','CO BOGOTA01','UY MONTEVI03','RCH SANTIAG05','RCH SANTIAG04','RCH CONCEPC01','RCH SANTIAG03','RCH VINADEL01','EC QUITO01','EC QUITO02')),
    ('Helena Bordera',6.74,('RCH SANTIAG05','ME MEXICO02','RCH SANTIAG01','RCH VALDIVI01')),
    ('Lucia Maria Capdevila',6.69,('US FLAGSTA01','US GREELEY01','US NEW-YOR01','JP KYOTO01','JP NISHINO01')),
    ('Emma Capilla',7.66,('KR SEOUL02','US MACOMB01','NZ HAMILTO01','JP KYOTO01')),
    ('Marcela Esperanza Carrascal',5.54,('RCH SANTIAG01','RCH SANTIAG05','AR BUENOSA01','RCH VINADEL01','RCH SANTIAG04','RCH SANTIAG02','ME MEXICO02','PE LIMA01','PE LIMA02','UY MONTEVI01','UY MONTEVI03','PY ASUNCIO01')),
    ('Roxana Iuliana',(('US TALLAHA01',10.37),('KAZ ASTANA01',10.37),('AR BUENOSA03',8.37),('US GREELEY01',10.37),('US MACOMB01',10.37),('NZ HAMILTO01',10.37),('TW TAICHUN01',10.37))),
    ('Dylan del castillo Dunn',11.48,('JP KYOTO01','')),
    ('Maria Diges',(('US TALLAHA01',7.96),('US CLEMSON',7.96),('AU ARMIDAL01',7.96),('HK HONGKON02',8.96),('TW TAICHUN01',8.96),('CDNMONTREA01 (FART)',8.96))),
    ('Victoria Dominguez',7.04,('RCH VALDIVI01','CO BOGOTA01','RCH SANTIAG02','EC QUITO02','RCH SANTIAG05')),
    ('María Díaz',7.02,('AU ARMIDAL01','')),
    ('Jose María Esteve',10.6,('US NEW-YOR01','')),
    ('Andrea Fernandez',10.19,('US NEW-YOR01','US FLAGSTA01','US MACOMB01','US GREELEY01','US CLEMSON','US PHILADE01','US CLARKSV01','US TEMPE01','US EDWARDS01','US COLUMBU01','US BEAUMON01')),
    ('Laura Ferrer',5.04,('JP NISHINO01','TW TAOYUAN01','TW TAICHUN01')),
    ('Marta Fetsyak',6.68,('TW TAICHUN01','BR SAOPAUL02','JP NISHINO01','BR FLORIAN01')),
    ('Carmen Fregenal',9.27,('US NEW-YOR01','US GREELEY01','NZ HAMILTO01','US FLAGSTA01')),
    ('Raúl García',6.23,('CO BOGOTA03','')),
    ('Carmen María García',7.43,('RCH SANTIAG04','RCH SANTIAG01','RCH SANTIAG05','RCH VINADEL01','RCH SANTIAG02','PE LIMA01','PE LIMA02')),
    ('Laura Lucía García',10.43,('US TALLAHA01','')),
    ('Elena Gómez',6.73,('RCH SANTIAG04','RCH SANTIAG02','RCH SANTIAG05','RCH SANTIAG03','RCH VINADEL01','RCH CONCEPC01','RCH VALDIVI01','PY ASUNCIO01')),
    ('Concepción Haro',6.49,('US TEMPE01','US MACOMB01','US GREELEY01','US FLAGSTA01','US COLUMBU01','US CLEMSON','US TALLAHA01','NZ HAMILTO01')),
    ('Jorge Hernández',7.66,('RCH VINADEL01','EC QUITO01','ME MEXICO02','UY MONTEVI01')),
    ('Lorena Daniela Herrera',0,('EC QUITO01','RCH SANTIAG05','EC QUITO02')),
    ('María Huesca',7.5,('VN HOCHIMI01','MY SUBANG-01')),
    ('Ana Ibarra',6.28,('AR SANTAFE01','AR BUENOSA03','UY MONTEVI01','RCH SANTIAG04','RCH VINADEL01','BR RIOJAN01','RCH SANTIAG05','CO BOGOTA01')),
    ('Vera Juan',7.25,('US TALLAHA01','US TEMPE01','US CLEMSON','US GREELEY01','US FLAGSTA01','US BEAUMON01','US EDWARDS01','US MACOMB01','US COLUMBU01')),
    ('Vanesa Lara',9.78,('DZ ORAN01','DZ ORAN02','DZ ALGER02 (FART)')),
    ('Liu Pengpeng',6.48,('TW TAICHUN01','MY SUBANG-01','JP KYOTO01','KR SEOUL02')),
    ('Melissa Llorca',8.11,('US CLEMSON','')),
    ('Josep Domenech Lurbe',7.34,('JP NISHINO01','TW TAICHUN01','TW TAOYUAN01','ME MEXICO02','PE LIMA01','PE LIMA03','AR BUENOSA03','RCH SANTIAG05','RCH VALDIVI01','RCH CONCEPC01','RCH SANTIAG01','RCH SANTIAG02','RCH SANTIAG03','EC QUITO01','BR RIOJAN01')),
    ('Enrique López',8.54,('KR SEOUL03','KR SEOUL02','TW TAOYUAN01','TW TAICHUN01')),
    ('Patricia Marhuenda',(('US NEW-YOR01',7.74),('US CLEMSON',7.74),('US MACOMB01',7.74),('US PHILADE01',7.74),('ME MEXICO02',6.74),('BR FLORIAN01',7.74),('BR RIOJAN01',7.74),('BR SAOPAUL02',7.74),('AR BUENOSA01',6.74),('JP KYOTO01',7.74))),
    ('Carles Martinez',6.27,('UY MONTEVI01','ME MEXICO02','AR BUENOSA03')),
    ('Guillermo Morales',10.23,('US TEMPE01','NZ HAMILTO01','AU ARMIDAL01','US NEW-YOR01')),
    ('Alejandra Martinez',(('US FLAGSTA01',9.95),('US NEW-YOR01',9.95),('US GREELEY01',9.95),('AR BUENOSA01',7.95),('RCH SANTIAG04',7.95),('RCH SANTIAG01',7.95),('AU ARMIDAL01',9.95),('NZ HAMILTO01',9.95))),
    ('Sara Martínez',6.61,('AR BUENOSA01','AR SANTAFE01','RCH SANTIAG02')),
    ('Víctor Mira',(('US TALLAHA01',8.64),('US EDWARDS01',8.64),('US GREELEY01',8.64),('US TEMPE01',8.64),('NZ HAMILTO01',8.64),('US FLAGSTA01',8.64),('US CLEMSON',8.64),('US BEAUMON01',8.64),('US MACOMB01',8.64),('US COLUMBU01',8.64),('AR BUENOSA03',5.64),('KR SEOUL03',8.64),('TW TAOYUAN01',8.64),('RCH SANTIAG05',5.64),('RCH VALPARA01',5.64))),
    ('Alicia Molina',9.84,('US TALLAHA01','US CLEMSON')),
    ('Diego Arturo Mora',7.55,('US NEW-YOR01','US PHILADE01','NZ HAMILTO01','US FLAGSTA01')),
    ('Álvaro Moya',(('CDNMONTREA01 (FART)',10.55),('TW TAICHUN01',10.55),('BR FLORIAN01',9.55),('NZ HAMILTO01',9.55),('CDNQUEBEC03',10.55))),
    ('Paola Muñoz',5.75,('AR SANTAFE01','RCH SANTIAG05','CO BOGOTA01','RCH SANTIAG01','RCH VINADEL01','EC QUITO01','PE LIMA01','CO CALI01')),
    ('Isabella Mävers',6.44,('AR SANTAFE01','')),
    ('Fabio Méndez',(('RCH VALDIVI01',6.91),('RCH CONCEPC01',6.91),('RCH SANTIAG03',6.91),('US EDWARDS01',7.91),('US MACOMB01',7.91),('US CLARKSV01',7.91),('US GREELEY01',7.91),('US TALLAHA01',7.91),('RCH SANTIAG04',6.91),('RCH VINADEL01',6.91),('EC QUITO02',6.91),('PY ASUNCIO01',6.91))),
    ('Aurora Nikolli',6.88,('US TALLAHA01','US TEMPE01')),
    ('Zainab Nadiri',5.71,('AR SANTAFE01','RCH SANTIAG05','CO BOGOTA01','RCH SANTIAG01','RCH VINADEL01','EC QUITO01','PE LIMA01','CO CALI01')),
    ('Fernando Navarro',(('KR SEOUL02',7.3),('NZ HAMILTO01',7.3),('AU ARMIDAL01',7.3),('JP TOKYO03',7.3),('BR SAOPAUL02',7.3),('MY KUALALU01',7.3),('JP KYOTO01',7.3),('CDN QUEBEC',9.3),('AR BUENOSA04',6.3),('CO BOGOTA01',6.3),('HK HONGKON01',7.3),('HK HONGKON02',7.3))),
    ('Nuria Navarro',(('US NEW-YOR01',8.49),('US FLAGSTA01',8.49),('US GREELEY01',8.49),('ME MEXICO02',6.49),('AR BUENOSA01',6.49),('BR BELOHOR01',8.49),('AU ARMIDAL01',8.49),('NZ HAMILTO01',8.49))),
    ('Paula Pellín',9.33,('US CLEMSON','US TEMPE01','US FLAGSTA01','US TALLAHA01')),
    ('Michelle Pernia',(('CO BOGOTA03',5.8),('ME MEXICO02',5.8),('US NEW-YOR01',6.8))),
    ('Alejandro Quiles',8.21,('JP KYOTO01','')),
    ('Leonardo Rodríguez',(('KAZ ASTANA01',7.06),('VN HOCHIMI01',7.06),('AR BUENOSA01',6.06),('JP TOKYO03',7.06),('JP NISHINO01',7.06),('AR SANTAFE01',6.06),('JP KYOTO01',7.06),('MY KUALALU01',7.06),('ME MEXICO02',6.06),('RCH SANTIAG01',6.06),('IN BANGALO01',7.06),('TW TAOYUAN01',7.06))),
    ('Isabel Rodríguez',6.5,('ME MEXICO02','AR BUENOSA01','RCH SANTIAG03','UY MONTEVI03','RCH SANTIAG01','UY MONTEVI01','RCH VALDIVI01','CO MEDELLI03','RCH SANTIAG04','RCH VINADEL01','PE LIMA02','CO BOGOTA03','AR SANTAFE01','RCH SANTIAG05','BR RIOJAN01')),
    ('Ismael Ruiz',10.1,('AU ARMIDAL01','NZ HAMILTO01','US NEW-YOR01')),
    ('Estela del mar Salcedo',5.87,('AR BUENOSA03','RCH SANTIAG05','RCH VALDIVI01')),
    ('Ananya Saratham',(('JP KYOTO01',6.69),('JP NISHINO01',6.69),('BR BELOHOR01',6.69),('ME MEXICO02',5.69),('AR BUENOSA01',5.69),('PE LIMA03',5.69),('EC QUITO03',5.69),('CO CALI01',5.69))),
    ('Aitor Silochi',6.29,('RCH SANTIAG04','RCH SANTIAG05','RCH VINADEL01')),
    ('Clara Sivila',8.6,('US EDWARDS01','US NEW-YOR01')),
    ('Dayana Samaniego',7.01,('UY MONTEVI01','')),
    ('Elena Sanz',8.79,('US TALLAHA01','US CLEMSON')),
    ('Sandra Sarrión',6.19,('RCH SANTIAG04','RCH SANTIAG05','RCH VINADEL01','RCH CONCEPC01','RCH SANTIAG03')),
    ('Neus serrano',10.58,('US GREELEY01','US TALLAHA01','US PHILADE01','US NEW-YOR01','US CLEMSON','US TEMPE01')),
    ('Neus Signes',9.01,('US FARMING01','')),
    ('Hanah Sánchez',(('AU ARMIDAL01',7.39),('NZ HAMILTO01',7.39),('JP TOKYO03',7.39),('JP NISHINO01',7.39),('JP KYOTO01',7.39),('US NEW-YOR01',7.39),('US COLUMBU01',7.39),('AR BUENOSA01',6.39),('AR SANTAFE01',6.39),('AR BUENOSA03',6.39))),
    ('Sara Urzainqui',6.79,('US NEW-YOR01','US GREELEY01','NZ HAMILTO01')),
    ('Denisa María Alexandra',(('AR BUENOSA01',5.97),('ME MEXICO02',5.97),('BR BELOHOR01',6.97),('CO CALI01',5.97))),
    ('Milagros Vasquez',8.1,('US GREELEY01','US TEMPE01','US FLAGSTA01','US BEAUMON01','US TALLAHA01')),
    ('Aimar Vega',(('NZ HAMILTO01',7.29),('AU ARMIDAL01',7.29),('UY MONTEVI01',6.29),('AR BUENOSA01',6.29),('EC QUITO01',6.29),('AR SANTAFE01',6.29),('UY MONTEVI03',6.29),('BO LA-PAZ01',6.29),('PY ASUNCIO01',6.29),('PE LIMA01',6.29),('PE LIMA02',6.29),('RCH VALDIVI01',6.29),('ME MEXICO02',6.29))),
    ('María del Juncal Vega',5.66,('RCH SANTIAG03','RCH SANTIAG01','RCH SANTIAG04','RCH SANTIAG05','RCH SANTIAG02','AR SANTAFE01')),
    ('Alba del Rey Nieto',6.53,('CDN QUEBEC',''))
    ]

universidades = []
for estudiante in alumnos:
    if len(estudiante)==3:
        for universidad in estudiante[2]:
            if universidad not in universidades:
                universidades.append(universidad)
    else:
        for universidad in estudiante[1]:
            if universidad[0] not in universidades:
                universidades.append(universidad[0])

universidades.pop(25)

plazas = []
for estudiante in alumnos:
    if len(estudiante)==3:
        for universidad in estudiante[2]:
            if universidad != '':
                plazas.append([estudiante[0],universidad,estudiante[1]])
    else:
        for tupla in estudiante[1]:
            if tupla[0] != '':
                plazas.append([estudiante[0],tupla[0],tupla[1]])


adjudicados = []
matriz = []
llenas = []

def BorraPersonas(array,persona):
    for i in range(len(array)):
        if array[i][0]==persona:
            array.pop(i)
    return array

def BorraPlazas(array,universidad):
    for i in range(len(array)):
        if array[i][1]==universidad:
            array.pop(i)
    return array


for i in range(len(plazas)):
    if plazas[i][0] not in adjudicados and plazas[i][1] not in llenas:
        matriz.append(plazas[i])
        adjudicados.append(plazas[i][0])
        llenas.append(plazas[i][1])

# def BuscaMáximo(array,universidad):
#     return 0

# definitivo=[]
# for universidad in universidades:
#     for i in range(len(plazas)):
#         posmax = BuscaMáximo(plazas,universidad)
#     definitivo.append((universidad,plazas[i][0]))
#     persona = plazas[i][0]
#     BorraPersonas(plazas,persona)
#     BorraPlazas(plazas,universidad)

# print(definitivo)
